# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
air_quality = pd.read_csv("../data/processed/air_quality_transformed.csv")
water_quality = pd.read_csv("../data/processed/water_quality_transformed.csv")
deforestation = pd.read_csv("../data/processed/deforestation_transformed.csv")

# %%
policies = {
    "Air Quality Policy": 2010,
    "Water Quality Improvement Act": 2015,
    "Deforestation Reduction Agreement": 2005,
}

# %%
print("Assessing Air Quality Policy...")
if 'Year' in air_quality.columns and 'Data Value' in air_quality.columns:
    air_quality_trend = air_quality.groupby('Year')['Data Value'].mean().reset_index()
# Out:
# Assessing Air Quality Policy...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=air_quality_trend, x='Year', y='Data Value', label='Air Quality Index')
plt.axvline(x=policies["Air Quality Policy"], color='red', linestyle='--', label='Policy Implementation (2010)')
plt.title('Air Quality Trend Over Time')
plt.xlabel('Year')
plt.ylabel('Average Air Quality Index')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Assessing Water Quality Policy...")
if 'Year' in water_quality.columns and 'pH_Filled' in water_quality.columns:
    water_quality_trend = water_quality.groupby('Year')['pH_Filled'].mean().reset_index()
# Out:
# Assessing Water Quality Policy...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=water_quality_trend, x='Year', y='pH_Filled', label='Average pH Level')
plt.axvline(x=policies["Water Quality Improvement Act"], color='green', linestyle='--', label='Policy Implementation (2015)')
plt.title('Water Quality Trend Over Time')
plt.xlabel('Year')
plt.ylabel('Average pH Level')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Assess Deforestation Policy
print("Assessing Deforestation Policy...")
if 'Year' in deforestation.columns and 'forest_change_percentage' in deforestation.columns:
    # Ensure no missing data in the relevant columns
    deforestation = deforestation.dropna(subset=['Year', 'forest_change_percentage'])
    
    # Calculate trend
    deforestation_trend = deforestation.groupby('Year')['forest_change_percentage'].mean().reset_index()
    
    # Visualize trends
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=deforestation_trend, x='Year', y='forest_change_percentage', label='Forest Area Change (%)')
    plt.axvline(x=policies["Deforestation Reduction Agreement"], color='blue', linestyle='--', label='Policy Implementation (2005)')
    plt.title('Deforestation Trend Over Time')
    plt.xlabel('Year')
    plt.ylabel('Average Forest Area Change (%)')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("Required columns for deforestation trend assessment are missing.")
# Out:
# Assessing Deforestation Policy...
# Required columns for deforestation trend assessment are missing.

# %%
print("\nPolicy Effectiveness Summary:")
for policy, year in policies.items():
    print(f"- {policy}: Implemented in {year}")
# Out:
# Policy Effectiveness Summary:
# - Air Quality Policy: Implemented in 2010
# - Water Quality Improvement Act: Implemented in 2015
# - Deforestation Reduction Agreement: Implemented in 2005
